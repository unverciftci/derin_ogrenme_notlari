# %% [markdown]
# # Makine Öğrenmesi İş Akışı
#
# ![IMG-0127.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Makine öğrenmesinde veriye uygun bir model seçiyoruz ve bu modelin bileşenlerini yani parametrelerini hesaplıyoruz. Bunun için veriyi modele sunup, modelden alınan tahmin ile olması gereken sonucu karşılaştırıyoruz. Elbette bir fark yani hata oluşuyor. Bu hatayı en aza indirmek için optimizasyon yöntemleri kullanıyoruz.

# %% [markdown]
# Örneğin kedi ve köpek resimlerini sınıflandırma problemimizi ele alalım. Elimizde 10000 tane etiketli fotoğraf olsun. Bunlardan 8000 tanesini modeli eğitmek için , 2000 tanesini de modelimizi değerlendirmek için kullanalım. Bunlara sırasıyla eğitim kümesi (training set) ve kıyaslama kümesi (test set) denir.
#
#
# ---
#
#
# Modelimiz eğitim kümesi kullanılarak eğitilirken, ortalama hatanın en aza indirilmesi gerekir. Burada hata fonksiyonuna kayıp fonksiyonu (loss function) denir. Hatayı en aza indirmek için optimzasyon yöntemleri kullanılır.
#
#
#
# ---
#
#
#
# Yapay sinir ağlarının eğitiminde veri ve model çok büyük olduğu için optimasyon yönteminin de hızlı bir algoritması olmalıdır. Bu yüzden genellikle sayısal yöntemler kullanılır. En çok kullanılan sayısal yöntem meyilli azalımdır.
